# %% [markdown]
# # Problem 2: Political Network Connections
#
# In this problem, you will analyze the network connections and strength between all persons and organizations in the *Trump World* using a combination of hash tables (i.e., dictionaries) and pandas dataframe.

# %% [markdown]
# ## The dataset
#
# The dataset for this problem is built from public records, news reports, and other sources on the Trump family, his Cabinet picks, and top advisers - more than 1,500 people and organizations altogether.
#
# Each row represents a connection between a person and an organization (e.g., The Trump Organization Inc. and Donald J. Trump), a person and another person (e.g., Donald J. Trump and Linda McMahon), or two organizations (e.g., Bedford Hills Corp. and Seven Springs LLC).
#
# Source: https://www.buzzfeednews.com/article/johntemplon/help-us-map-trumpworld
#
# Before starting, please run the following cell to set up the environment and import the data to `Network`.

# %%
import math
import pandas as pd
import numpy as np
from collections import defaultdict
Network = pd.read_csv("../resource/asnlib/publicdata/network.csv",encoding='latin-1' )
assert len(Network) == 3380
Network.head()
# Out:
#   Entity A Type                            Entity A Entity B Type  \
# 0  Organization     4 SHADOW TREE LANE MEMBER CORP.  Organization
# 1  Organization  40 WALL DEVELOPMENT ASSOCIATES LLC  Organization
# 2  Organization                  40 WALL STREET LLC  Organization
# 3  Organization         40 WALL STREET MEMBER CORP.  Organization
# 4  Organization                401 MEZZ VENTURE LLC  Organization
#
#                         Entity B  Connection_Strength
# 0         4 SHADOW TREE LANE LLC             0.469155
# 1             40 WALL STREET LLC             0.035480
# 2  40 WALL STREET COMMERCIAL LLC             0.177874
# 3             40 WALL STREET LLC             0.236508
# 4   401 NORTH WABASH VENTURE LLC             0.169532

# %% [markdown]
# **Exercise 0** (1 points). Create a subset of the data frame named `Network_sub`, keeping only records where `Entity B` contains the keyword "TRUMP" (not case sensitive).

# %%
Network_sub = Network.copy()
Network_sub = Network_sub[Network_sub['Entity B'].str.contains('TRUMP', regex=True)]

# %%
# Test cell: `test_subset`

assert type(Network_sub)==pd.DataFrame, "Your subset is not a panda dataframe"
assert list(Network_sub)==['Entity A Type','Entity A','Entity B Type','Entity B','Connection_Strength'], "Your subset columns are not consistent with the master dataset"
assert len(Network_sub)==648, "The length of your subset is not correct"

test = Network_sub.sort_values(by='Connection_Strength')
test.reset_index(drop=True, inplace=True)
assert test.loc[0,'Connection_Strength']==0.001315204
assert test.loc[200,'Connection_Strength']==0.312599997
assert test.loc[400,'Connection_Strength']==0.610184514
assert test.loc[647,'Connection_Strength']==0.996641965

print("\n(Passed.)")
# Out:
# (Passed.)

# %% [markdown]
# Now, let's take a look at part of the `Network_sub` data.

# %%
#Network_sub[25:36]
Network_sub[(Network_sub['Entity A'] == 'DONALD J. TRUMP') & (Network_sub['Entity B Type'] == 'Person')]
# Out:
#     Entity A Type         Entity A Entity B Type              Entity B  \
# 584        Person  DONALD J. TRUMP        Person      DONALD TRUMP JR.
# 674        Person  DONALD J. TRUMP        Person            ERIC TRUMP
# 709        Person  DONALD J. TRUMP        Person          IVANKA TRUMP
# 758        Person  DONALD J. TRUMP        Person  MARYANNE TRUMP BARRY
# 761        Person  DONALD J. TRUMP        Person         MELANIA TRUMP
#
#      Connection_Strength
# 584             0.453991
# 674             0.468002
# 709             0.773875
# 758             0.330120
# 761             0.517144

# %% [markdown]
# **Exercise 1** (4 points). Write a function
#
# ```python
# def Connection_Strength(Network_sub, Entity_B_Type)
# ```
#
# that takes two inputs
#
# 1. `Network_sub` is the dataset you get from exercise 0
# 2. `Entity_B_Type` can take two values: either `Person` or `Organization`
#
# and for every entity A that is connected to entity B, based on the type of entity B, returns a nested dictionary (i.e. dictionary of dictionaries) of the form:
#
# ```python
# {Entity A: {Entity B: Connection_Strength, Entity B: Connection_Strength}, ... }```
#
# For example: for entity A that is connected to entity B of type person, the function will return something like the following:
#
# ```python
# {'DONALD J. TRUMP': {'DONALD TRUMP JR.': 0.453990548,
#   'ERIC TRUMP': 0.468002101,
#   'IVANKA TRUMP': 0.773874808,
#   'MARYANNE TRUMP BARRY': 0.330120053,
#   'MELANIA TRUMP': 0.5171444000000001},
#  'DONALD J. TRUMP FOR PRESIDENT, INC.': {'DONALD J. TRUMP': 0.377887355},
#  'DONALD TRUMP JR.': {'ERIC TRUMP': 0.405052388, 'VANESSA TRUMP': 0.025756815},
#  'GRACE MURDOCH': {'IVANKA TRUMP': 0.966637541},
#  'IVANKA M. TRUMP BUSINESS TRUST': {'IVANKA TRUMP': 0.141785871}, ...}```

# %%
def Connection_Strength(Network_sub, Entity_B_Type):
    assert type(Entity_B_Type) == str
    assert Entity_B_Type in ['Person', 'Organization']
    
    P = {}
    

    for i in set(Network_sub['Entity A'][Network_sub['Entity B Type'] == Entity_B_Type]):
        
        df = Network_sub[(Network_sub['Entity A'] == i) & (Network_sub['Entity B Type'] == Entity_B_Type)]     
        J = {}
        
        for j in set(df['Entity B']):
            df1 = df[Network_sub['Entity B'] == j]
            J.update({j:df1['Connection_Strength'].iloc[0]})
        
        P.update({i:J})
                    
    return P
        
    
P = Connection_Strength(Network_sub, 'Person')

P['DONALD J. TRUMP']


#len(set(Network_sub['Entity A'][Network_sub['Entity B Type'] == 'Person']))
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# {'DONALD TRUMP JR.': 0.453990548,
#  'IVANKA TRUMP': 0.773874808,
#  'ERIC TRUMP': 0.468002101,
#  'MARYANNE TRUMP BARRY': 0.330120053,
#  'MELANIA TRUMP': 0.5171444000000001}

# %%
# Test Cell: `Connection_Strength`

# Create a dictonary 'Person' for entity B of type person
Person = Connection_Strength(Network_sub, 'Person')
# Create a dictionary 'Organization' for entity B of type organization
Organization = Connection_Strength(Network_sub, 'Organization')

assert type(Person)==dict or defaultdict, "Your function does not return a dictionary"
assert len(Person)==17, "Your result is wrong for entity B of type person"
assert len(Organization)==296, "Your result is wrong for entity B of type organization"

assert Person['DONALD J. TRUMP']=={'DONALD TRUMP JR.': 0.453990548,'ERIC TRUMP': 0.468002101,'IVANKA TRUMP': 0.773874808,
  'MARYANNE TRUMP BARRY': 0.330120053,'MELANIA TRUMP': 0.5171444000000001}, "Wrong result"
assert Person['DONALD J. TRUMP FOR PRESIDENT, INC.']=={'DONALD J. TRUMP': 0.377887355}, "Wrong result"
assert Person['WENDI DENG MURDOCH']=={'IVANKA TRUMP': 0.669636181}, "Wrong result"

assert Organization['401 MEZZ VENTURE LLC']=={'TRUMP CHICAGO RETAIL LLC': 0.85298544}, "Wrong result"
assert Organization['ACE ENTERTAINMENT HOLDINGS INC']=={'TRUMP CASINOS INC.': 0.202484568,'TRUMP TAJ MAHAL INC.': 0.48784823299999996}, "Wrong result"
assert Organization['ANDREW JOBLON']=={'THE ERIC TRUMP FOUNDATION': 0.629688777}, "Wrong result"

print("\n(Passed.)")
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# (Passed.)

# %% [markdown]
# **Exercise 2** (1 point). For the dictionary `Organization` **created in the above test cell**, create another dictionary `Organization_avg` which for every entity A gives the average connection strength (i.e., the average of nested dictionary values). `Organization_avg` should be in the following form:
# ```python
# {Entity A: avg_Connection_Strength, Entity A: avg_Connection_Strength, ... }```

# %%
Organization_avg = {}

for key, value in Organization.items():
    vals = []
    for key2, value2 in value.items():
        vals.append(value2)
    avg = sum(vals) / len(vals)
    Organization_avg.update({key:avg})
    
Organization_avg
# Out:
# {'RICK GATES': 0.059203658,
#  'TRUMP OLD POST OFFICE MEMBER CORP.': 0.488701118,
#  'BILL STEPIEN': 0.43057139200000005,
#  'RUSSELL FLICKER': 0.54442625,
#  'TRUMP PARK AVENUE ACQUISITION LLC': 0.19060126300000002,
#  'THC CHINA DEVELOPMENT MANAGEMENT CORP.': 0.012192929,
#  'IT OPERATIONS MANAGING MEMBER CORP': 0.6276018636666667,
#  'LARRY GLICK': 0.826571173,
#  'SENTIENT JETS MEMBER CORP.': 0.449202121,
#  'HOPE HICKS': 0.43825646050000006,
#  'TRUMP PLAZA ASSOCIATES LLC': 0.5092408589999999,
#  'TRUMP PRODUCTIONS MANAGING MEMBER, INC.': 0.46170153799999997,
#  'TIHM MEMBER CORP.': 0.460458405,
#  'JASON D. GREENBLATT': 0.6174344325000001,
#  'TRUMP WORLD PRODUCTIONS MANAGER CORP.': 0.996641965,
#  'TRUMP MARKS EGYPT CORP.': 0.158861101,
#  'T INTERNATIONAL REALTY LLC': 0.37724370399999996,
#  'THE TRUMP ENTREPRENEUR INITIATIVE LLC (NY DOMESTIC)': 0.3195141455,
#  'MATTHEW CALAMARI, JR.': 0.7601921509999999,
#  'MICHAEL SEXTON': 0.511707929,
#  'TRUMP GOLF COCO BEACH MEMBER CORP.': 0.576517368,
#  'TRUMP MARKS JERSEY CITY CORP.': 0.28973806,
#  'RONALD C. LIEBERMAN': 0.8361105440000001,
#  'TRUMP OCEAN MANAGER, INC.': 0.35977641,
#  'THCR ENTERPRISES, LLC': 0.296792309,
#  'TRUMP INDIANA REALTY, LLC': 0.045631701,
#  'HUSSAIN ALI SAJWANI': 0.974541051,
#  'MATTHEW CALAMARI': 0.755426239,
#  'MGM TELEVISION': 0.9765446179999999,
#  'NATIONALIST CONGRESS PARTY (INDIA)': 0.140406204,
#  'JUPITER GOLF CLUB MANAGING MEMBER CORP.': 0.49468827,
#  'RHONA GRAFF RICCIO': 0.42709790400000003,
#  'TRUMP CHICAGO RETAIL MEMBER CORP.': 0.662171098,
#  'TRUMP MARKS GP CORP.': 0.845373279,
#  'TIGL IRELAND ENTERPRISES LIMITED': 0.235779897,
#  'TRUMP ENDEAVOR 12 MANAGER CORP.': 0.69554839,
#  'TRUMP LAS VEGAS CORP.': 0.690012058,
#  'TRUMP MARKS ATLANTA MEMBER CORP.': 0.401384974,
#  'PUTNAM INVESTMENTS': 0.45602732799999995,
#  'TRUMP VINEYARD ESTATES LOT 3 OWNER LLC': 0.6560425670000001,
#  'GREENBERG TRAURIG LLP': 0.7652605159999999,
#  'MADISON AVENUE DIAMONDS': 0.703880838,
#  'TRUMP MARKS PRODUCTS MEMBER CORP.': 0.48330756700000005,
#  'TRUMP MARKS CHICAGO MEMBER CORP.': 0.791241414,
#  '401 MEZZ VENTURE LLC': 0.85298544,
#  'JONATHAN SPITALNY': 0.623534696,
#  'TRUMP VIRGINIA ACQUISITIONS MANAGER CORP.': 0.381695897,
#  'TRUMP CPS CORP.': 0.661147835,
#  'CHEVY CHASE TRUST HOLDINGS, INC.': 0.92542216,
#  'TRUMP HOTELS & CASINO RESORTS DEVELOPMENT COMPANY, LLC': 0.303722358,
#  'TRUMP NATIONAL GOLF CLUB LLC': 0.53541255,
#  'THE VANGUARD GROUP, INC.': 0.444794989,
#  'BRIARCLIFF PROPERTIES, INC.': 0.102998005,
#  'TRUMP HOTELS & CASINO RESORTS FUNDING, INC.': 0.16822045300000002,
#  'LARA LEE YUNASKA': 0.085203475,
#  'TRIBUTARY FUNDS': 0.275389968,
#  'TRUMP INDIANA, INC.': 0.062501805,
#  'TRUMP INTERNET CASINO, LLC': 0.6260362979999999,
#  'TRUMP MARKS BAJA CORP.': 0.850795505,
#  'TRUMP MARKS HOLDINGS, L.P.': 0.4056019685,
#  'TRUMP MARKS MENSWEAR MEMBER CORP.': 0.198714568,
#  'TRUMP MARKS PANAMA CORP.': 0.9195362890000001,
#  'TRUMP SCOTSBOROUGH SQUARE MEMBER CORP.': 0.508324323,
#  'VIKTOR KHRAPUNOV': 0.563762576,
#  'TRUMP ATLANTIC CITY HOLDING, INC.': 0.41390016,
#  'TRUMP CHICAGO HOTEL MEMBER CORP.': 0.11259767,
#  'VH PROPERTY CORP.': 0.245558081,
#  'TRUMP DEVELOPMENT SERVICES MEMBER CORP.': 0.9402308890000001,
#  'SENTIENT JETS LLC': 0.658130125,
#  'MARTIN JAJAN': 0.30949812,
#  'RICK DEARBORN': 0.336765579,
#  'THE HARTFORD': 0.494252798,
#  'DSN LICENSING LLC': 0.24017932399999997,
#  'TRUMP MARKS ASIA CORP.': 0.9750428870000001,
#  'LFB ACQUISITION LLC': 0.629014822,
#  'TRUMP CHICAGO RESIDENTIAL MEMBER CORP.': 0.27739491899999996,
#  'TRUMP NATIONAL GOLF CLUB COLTS NECK MEMBER CORP.': 0.977906232,
#  'TRUMP OCEAN MANAGING MEMBER LLC': 0.58748783,
#  'JEFF WAGONER': 0.458408985,
#  'ANNE-MARIE DONOGHUE': 0.741396567,
#  'MISS UNIVERSE L.P., LLLP': 0.781769305,
#  'JILL MARTIN': 0.872985329,
#  'THCR ENTERPRISES, INC.': 0.647483723,
#  'TRUMP MARKS TORONTO CORP.': 0.933210834,
#  'THE TRUMP ENTREPRENEUR INITIATIVE LLC': 0.37633556799999995,
#  'CHRISTL MAHFOUZ': 0.42678026399999996,
#  'PIONEER INVESTMENTS': 0.034029252999999995,
#  'TRUMP VINEYARD ESTATES LLC': 0.88250679,
#  'TRUMP MARKS FINE FOODS MEMBER CORP.': 0.31929283199999997,
#  'TRUMP MARKS ISTANBUL II CORP.': 0.357800009,
#  'TRUMP SCOTLAND MEMBER INC': 0.478040099,
#  'TIHH MEMBER CORP.': 0.296643323,
#  'TNGC PINE HILL MEMBER CORP.': 0.9192956320000001,
#  'TNGC PINE HILL LLC': 0.543454626,
#  'ANDREW GRAVES': 0.164851306,
#  'TRUMP MARKS WAIKIKI CORP.': 0.9600882559999999,
#  'SCOUT INVESTMENTS': 0.328805322,
#  'TRUMP CLASSIC CARS MEMBER CORP.': 0.8937897290000001,
#  'FELIX SATER': 0.17056705,
#  'TRUMP CHICAGO COMMERCIAL MEMBER CORP.': 0.02101472,
#  'THCR VENTURES, INC.': 0.051931454,
#  'TIPPERARY REALTY CORP.': 0.289156071,
#  'DIANNA BALABON': 0.18625114199999998,
#  'MICHELLE CARLSON': 0.753507739,
#  'TRUMP INDIANA CASINO MANAGEMENT, LLC': 0.533522382,
#  'SHAUN CAIN': 0.502038849,
#  'HYDE PARK, LLC': 0.17687677100000002,
#  'TRUMP MARKS WESTCHESTER CORP.': 0.898137155,
#  'TRUMP RUFFIN TOWER I LLC': 0.439921038,
#  'IVANKA TRUMP': 0.32375837399999996,
#  'THOMAS M. SPARICO': 0.348134995,
#  'TRUMP DRINKS ISRAEL MEMBER CORP.': 0.617577911,
#  'AETOS SA': 0.516288066,
#  'TRUMP RIVERSIDE MANAGEMENT LLC': 0.312599997,
#  'TRUMP MARKS HOLLYWOOD CORP.': 0.344895465,
#  'TRUMP PANAMA CONDOMINIUM MEMBER CORP.': 0.06976787400000001,
#  'TAMIR SAPIR': 0.622889867,
#  'TRUMP MARINA ASSOCIATES, L.P.': 0.266293318,
#  'MICHAEL J. BOCCIO': 0.510080568,
#  'TRUMP MIAMI RESORT MANAGEMENT MEMBER CORP.': 0.645157038,
#  'MARK BURNETT PRODUCTIONS': 0.646513337,
#  'ANDREW WEISS': 0.267608145,
#  'TRUMP DELMONICO LLC': 0.9502770359999999,
#  'TRUMP TAJ MAHAL ASSOCIATES': 0.778367308,
#  'BOBBY BURCHFIELD': 0.8331036140000001,
#  'DJT HOLDINGS MANAGING MEMBER LLC': 0.006670199,
#  'TRUMP MARKS CANOUAN CORP.': 0.5833057979999999,
#  'NORTHERN TRUST': 0.5931346270000001,
#  'SMC OCEAN LLC': 0.625716956,
#  'TIHH MEMBER LLC': 0.579557688,
#  'TRUMP ORGANIZATION LLC': 0.951711911,
#  'TRUMP UNIVERSITY CA LLC': 0.209298567,
#  'TRUMP MARKS SOHO LICENSE CORP.': 0.550958995,
#  'JUPITER GOLF CLUB LLC': 0.180985867,
#  'TRUMP NATIONAL GOLF CLUB WASHINGTON DC MEMBER CORP.': 0.520483529,
#  'TRUMP EU MARKS MEMBER CORP.': 0.170942932,
#  'THCR MANAGEMENT SERVICES, LLC': 0.429505332,
#  'TRUMP INTERNATIONAL GOLF CLUB, INC.': 0.264930558,
#  'THC CHINA DEVELOPMENT LLC': 0.979432187,
#  'TRUMP FERRY POINT MEMBER CORP.': 0.6274150070000001,
#  'VLADIMIR POTANIN': 0.568326742,
#  'SONJA TALESNIK': 0.602409305,
#  'DSN LICENSING MEMBER CORP.': 0.494239449,
#  'TRUMP WINERY': 0.19569239,
#  'LEIB WALDMAN': 0.8975499709999999,
#  'BRITTANY HEBERT': 0.724912819,
#  'TW VENTURE II LLC': 0.416194261,
#  'JAMES BURNHAM': 0.187474088,
#  'DAEWOO AMERICA DEVELOPMENT (NEW YORK) CORP.': 0.618116303,
#  'TRUMP MARKS SUNNY ISLES I MEMBER CORP.': 0.59254972,
#  'MUKEMMEL SARIMSAKCI': 0.6846734170000001,
#  'DANIEL RIDLOFF': 0.6071956589999999,
#  'BRIAN BAUDREAU': 0.24950579899999997,
#  'STEVEN LEVINE': 0.863944211,
#  'DONALD TRUMP JR.': 0.60533119475,
#  '401 NORTH WABASH VENTURE LLC': 0.559004782,
#  'GARY K. NG': 0.80033053,
#  'TRUMP INTERNATIONAL GOLF CLUB - FLORIDA': 0.009409518,
#  'TRUMP PLAZA ASSOCIATES': 0.035647393,
#  'TRUMP FLORIDA MANAGER CORP.': 0.831983989,
#  'TRUMP INTERNATIONAL DEVELOPMENT MEMBER CORP.': 0.692512474,
#  'TRUMP MARKS PUERTO RICO II MEMBER CORP.': 0.655431085,
#  'LSH BARRA': 0.196348795,
#  'INVESCO LTD.': 0.595319336,
#  'ROBERT F. GRIFFIN': 0.28877359199999997,
#  'TRUMP ENTERTAINMENT RESORTS, INC.': 0.9519249909999999,
#  'TRUMP CASINO HOLDINGS, LLC': 0.938881105,
#  'RICARDO HAZOURY': 0.24406768199999998,
#  'GOLF RECREATION SCOTLAND LIMITED': 0.7060768359999999,
#  'INVESTORS SAVINGS BANK': 0.91632813,
#  'TRUMP BOOKS MANAGER CORP.': 0.459112246,
#  'TRUMP LAS VEGAS MANAGING MEMBER LLC': 0.910634627,
#  'AMBOY BANK': 0.848742007,
#  'DAN SCAVINO': 0.359703302,
#  'TRAVEL ENTERPRISES MANAGEMENT INC': 0.43567053299999997,
#  'ASHLEY THOMPSON SIDMAN': 0.154176764,
#  'TRUMP MARKS MUMBAI MEMBER CORP.': 0.434221662,
#  'SLC TURNBERRY LIMITED': 0.680717389,
#  'TRUMP RUFFIN LLC': 0.38553988,
#  'YY DEVELOPMENT GROUP': 0.308922521,
#  'ERIC TRUMP': 0.43395897840000003,
#  'DJT HOLDINGS LLC': 0.5855800477222223,
#  'RUSSELL INVESTMENTS': 0.852217245,
#  'TRUMP TOWER MANAGING MEMBER, INC.': 0.727837307,
#  'THCR MANAGEMENT HOLDINGS, LLC': 0.271812797,
#  'TRUMP MARKS TAMPA CORP.': 0.046778507999999996,
#  'TRUMP TORONTO MEMBER CORP.': 0.6462387975,
#  'CHARLES P. REISS': 0.9374582379999999,
#  'MICHAEL D. COHEN': 0.5907252485,
#  'TEVFIK ARIF': 0.6134469810000001,
#  'JOHN MCENTEE': 0.512171955,
#  'TRUMP INTERNATIONAL HOTELS MANAGEMENT LLC': 0.909083359,
#  'TRUMP MARKS PHILADELPHIA CORP.': 0.041982509,
#  'KATHLEEN M. MCSWEENEY': 0.399225534,
#  'TRUMP LAS OLAS MEMBER CORP.': 0.7570479529999999,
#  'TRUMP NATIONAL GOLF CLUB MEMBER CORP.': 0.67948812,
#  'TRUMP ACQUISITION CORP.': 0.436492626,
#  'ALAN GARTEN': 0.569393601,
#  'DELAWARE MANAGEMENT HOLDINGS, INC.': 0.329218131,
#  'DJT ENTREPRENEUR MEMBER LLC': 0.767322671,
#  'STEPHEN MILLER': 0.039524425,
#  'JAN SCHECK': 0.201858066,
#  'TRUMP MARKS BATUMI MANAGING MEMBER CORP.': 0.8463251409999999,
#  'TRUMP MARKS MAGAZINE CORP.': 0.78198022,
#  'TRUMP AC CASINO MARKS MEMBER CORP.': 0.777092188,
#  'TRUMP MARKS PUERTO RICO I MEMBER CORP.': 0.848776544,
#  'TRUMP HOME MARKS MEMBER CORP.': 0.208219796,
#  'TRUMP MARKS LAS VEGAS CORP.': 0.035438912999999996,
#  'SEI INVESTMENTS COMPANY': 0.106729404,
#  'GEORGE SORIAL': 0.6418813045,
#  'ALLIANCEBERNSTEIN LP': 0.7857781209999999,
#  'TRUMP VIRGINIA LOT 5 MANAGER CORP.': 0.6751891999999999,
#  'TRUMP SALES & LEASING CHICAGO MEMBER CORP.': 0.76192738,
#  'ABE WALLACH': 0.45290101,
#  'GEPT DELMONICO LLC': 0.42071105200000003,
#  'TRUMP MARKS PUNTA DEL ESTE MANAGER CORP.': 0.59303706,
#  'PIMCO': 0.6567878429999999,
#  'DANIEL M. MCFADDEN': 0.382650196,
#  'MICHAEL P. MELLON': 0.82060454,
#  'THCR FUNDING': 0.045426432999999995,
#  'LADDER CAPITAL FINANCE LLC': 0.1772044015,
#  'TRUMP PANAMA HOTEL MANAGEMENT MEMBER CORP.': 0.6940041459999999,
#  'LYNNE M PATTON': 0.9244356859999999,
#  'TRUMP MARKS MORTGAGE CORP.': 0.781976916,
#  'SARA MARTENS': 0.305270838,
#  'RPV DEVELOPMENT LLC': 0.8061220509999999,
#  'ERIC DANZIGER': 0.20536450899999997,
#  'ALLEN WEISSELBERG': 0.6291805524,
#  'TRUMP ENDEAVOR 12 LLC': 0.041866446,
#  'TRUMP CANOUAN ESTATE MEMBER CORP.': 0.027253791,
#  'FIDELITY INVESTMENTS': 0.14185534,
#  'TRUMP ATLANTIC CITY FUNDING, INC.': 0.838293388,
#  'PRUDENTIAL FINANCIAL': 0.9203346170000001,
#  'THE TRUMP-EQUITABLE FIFTH AVENUE COMPANY': 0.26874007699999997,
#  'TNGC CHARLOTTE MANAGER CORP.': 0.56582613,
#  'TRUMP CAROUSEL MEMBER CORP.': 0.18586170300000002,
#  'THE TRUMP ORGANIZATION, INC.': 0.643076382,
#  'CHEN SITING AKA CHARLYNE CHEN': 0.137199374,
#  'TRUMP KOREAN PROJECTS LLC': 0.9344614090000001,
#  'TRUMP MARKS BEVERAGES CORP.': 0.586155141,
#  'TRUMP MARKS NEW ROCHELLE CORP.': 0.42854435399999996,
#  'THE TRUMP MARKS REAL ESTATE CORP.': 0.897744311,
#  'TNGC DUTCHESS COUNTY MEMBER CORP.': 0.189439805,
#  'THCR HOLDING CORP.': 0.318136623,
#  'UNITED ARTISTS MEDIA GROUP': 0.222295565,
#  'TNGC DUTCHESS COUNTY LLC': 0.156848808,
#  'ANDREW JOBLON': 0.629688777,
#  'DONALD J. TRUMP': 0.48782770501449263,
#  'THE TRUMP FOLLIES MEMBER INC.': 0.848384129,
#  'BRIAN ASIDMAN': 0.985400093,
#  'NEW WORLD PROPERTY MANAGEMENT LIMITED': 0.5167702270000001,
#  'THE DONALD J. TRUMP REVOCABLE TRUST': 0.318124755,
#  'TMG MEMBER, LLC': 0.721729108,
#  'E.J. RIDINGS': 0.295766244,
#  'TRUMP MARKS MATTRESS MEMBER CORP.': 0.865628017,
#  'TRUMP WINE MARKS MEMBER CORP.': 0.039020858,
#  'TRUMP ATLANTIC CITY FUNDING II, INC.': 0.569229336,
#  'HAL GOLDMAN': 0.7735002440000001,
#  'FLIGHTS INC.': 0.13344002900000002,
#  'PAVEL FUKS': 0.17351538800000002,
#  'TRUMP MARKS PALM BEACH CORP.': 0.37239347700000003,
#  'ANNIE VELTRI': 0.6349027660000001,
#  'TRUMP MARKS DUBAI CORP.': 0.554671661,
#  'TRUMP MARKS PHILIPPINES CORP.': 0.475114185,
#  'ANAR MAMMADOV': 0.95595441,
#  'TRUMP ATLANTIC CITY FUNDING III, INC.': 0.026668814,
#  'TRUMP PLAZA MEMBER INC.': 0.20106308349999996,
#  'OMAROSÉ ONEE MANIGAULT': 0.747649135,
#  'FIRST MEMBER, INC.': 0.33906804799999996,
#  'TRUMP MARKS SUNNY ISLES II MEMBER CORP.': 0.700992217,
#  'DEUTSCHE BANK': 0.922834157,
#  'THCR/LP CORPORATION': 0.491754819,
#  'TRUMP HOTELS & CASINO RESORTS HOLDINGS, L.P.': 0.95427914,
#  'TRUMP ATLANTIC CITY CORPORATION': 0.432218624,
#  'TRUMP DRINKS ISRAEL HOLDINGS MEMBER CORP.': 0.809092368,
#  'TRUMP MARKS STAMFORD CORP.': 0.580283886,
#  'TRUMP CASINO FUNDING, INC.': 0.9423668940000001,
#  'TRUMP 845 UN MGR CORP.': 0.84826228,
#  'TRUMP REALTY SERVICES, LLC': 0.17022058199999998,
#  'TRUMP VINEYARD ESTATES MANAGER CORP.': 0.133637214,
#  'TRUMP LAS VEGAS MEMBER LLC': 0.008820483,
#  'TRUMP MARKS FT. LAUDERDALE MEMBER CORP.': 0.72740976,
#  'NATIONWIDE MUTUAL INSURANCE COMPANY': 0.377571751,
#  'TONY TIAH THEE KIAN': 0.803550207,
#  'TRUMP ATLANTIC CITY ASSOCIATES': 0.744171895,
#  'DAEWOO AMERICA DEVELOPMENT (NEW YORK) CORP': 0.994784752,
#  'TRUMP MARINA, INC.': 0.591528466,
#  'TRUMP MARKS WHITE PLAINS CORP.': 0.515147593,
#  'VOYA FINANCIAL': 0.360430187,
#  'DON MCGAHN': 0.45896760766666667,
#  'TRUMP MARKS TORONTO LP': 0.30419530899999997,
#  'DJT ENTREPRENEUR MANAGING MEMBER LLC': 0.001315204,
#  'MADHUKAR TULSI': 0.580115663,
#  'ACE ENTERTAINMENT HOLDINGS INC': 0.34516640049999997,
#  'JT FOXX': 0.293072917,
#  'USAA': 0.7545823909999999}

# %%
# Test Cell: `Organization_avg`
assert type(Organization_avg)==dict or defaultdict, "Organization_avg is not a dictionary"
assert len(Organization_avg)==len(Organization)

for k_, v_ in {'401 MEZZ VENTURE LLC': 0.85298544,
               'DJT HOLDINGS LLC': 0.5855800477222223,
               'DONALD J. TRUMP': 0.4878277050144927,
               'JAMES BURNHAM': 0.187474088}.items():
    print(k_, Organization_avg[k_], v_)
    assert math.isclose(Organization_avg[k_], v_, rel_tol=4e-15*len(Organization[k_])), \
           "Wrong result for '{}': Expected {}, got {}".format(k_, v_, Organization_avg[k_])

print("\n(Passed.)")
# Out:
# 401 MEZZ VENTURE LLC 0.85298544 0.85298544
# DJT HOLDINGS LLC 0.5855800477222223 0.5855800477222223
# DONALD J. TRUMP 0.48782770501449263 0.4878277050144927
# JAMES BURNHAM 0.187474088 0.187474088
#
# (Passed.)

# %% [markdown]
# **Exercise 3** (4 points). Based on the `Organization_avg` dictionary you just created, determine which organizations have an average connection strength that is strictly greater than a given threshold, `THRESHOLD` (defined in the code cell below). Then, create a new data frame named `Network_strong` that has a subset of the rows of `Network_sub` whose `Entity A` values match these organizations **and** whose `"Entity B Type"` equals `"Organization"`.

# %%
THRESHOLD = 0.5
new = {k: v for k, v in Organization_avg.items() if v > .5}

new_orgs = list(new.keys())



Network_strong = Network_sub[Network_sub['Entity A'].isin(new_orgs)]

Network_strong = Network_strong[Network_strong['Entity B Type'] == 'Organization']

Network_strong
# Out:
#      Entity A Type                                           Entity A  \
# 5     Organization                               401 MEZZ VENTURE LLC
# 6     Organization                       401 NORTH WABASH VENTURE LLC
# 7     Organization                       401 NORTH WABASH VENTURE LLC
# 20    Organization                                           AETOS SA
# 25          Person                                        ALAN GARTEN
# 49          Person                                  ALLEN WEISSELBERG
# 50          Person                                  ALLEN WEISSELBERG
# 51          Person                                  ALLEN WEISSELBERG
# 53          Person                                  ALLEN WEISSELBERG
# 54          Person                                  ALLEN WEISSELBERG
# 56    Organization                               ALLIANCEBERNSTEIN LP
# 59    Organization                                         AMBOY BANK
# 73          Person                                      ANAR MAMMADOV
# 90          Person                                      ANDREW JOBLON
# 107         Person                                ANNE-MARIE DONOGHUE
# 109         Person                                       ANNIE VELTRI
# 226         Person                                   BOBBY BURCHFIELD
# 231         Person                                      BRIAN ASIDMAN
# 238         Person                                    BRITTANY HEBERT
# 280         Person                                   CHARLES P. REISS
# 284   Organization                   CHEVY CHASE TRUST HOLDINGS, INC.
# 326   Organization         DAEWOO AMERICA DEVELOPMENT (NEW YORK) CORP
# 327   Organization        DAEWOO AMERICA DEVELOPMENT (NEW YORK) CORP.
# 340         Person                                     DANIEL RIDLOFF
# 417   Organization                                      DEUTSCHE BANK
# 427   Organization                        DJT ENTREPRENEUR MEMBER LLC
# 438   Organization                                   DJT HOLDINGS LLC
# 439   Organization                                   DJT HOLDINGS LLC
# 440   Organization                                   DJT HOLDINGS LLC
# 441   Organization                                   DJT HOLDINGS LLC
# ...            ...                                                ...
# 3070  Organization                     TRUMP MARKS SOHO LICENSE CORP.
# 3071  Organization                         TRUMP MARKS STAMFORD CORP.
# 3072  Organization             TRUMP MARKS SUNNY ISLES I MEMBER CORP.
# 3073  Organization            TRUMP MARKS SUNNY ISLES II MEMBER CORP.
# 3075  Organization                          TRUMP MARKS TORONTO CORP.
# 3077  Organization                          TRUMP MARKS WAIKIKI CORP.
# 3078  Organization                      TRUMP MARKS WESTCHESTER CORP.
# 3079  Organization                     TRUMP MARKS WHITE PLAINS CORP.
# 3080  Organization         TRUMP MIAMI RESORT MANAGEMENT MEMBER CORP.
# 3082  Organization   TRUMP NATIONAL GOLF CLUB COLTS NECK MEMBER CORP.
# 3083  Organization                       TRUMP NATIONAL GOLF CLUB LLC
# 3084  Organization              TRUMP NATIONAL GOLF CLUB MEMBER CORP.
# 3085  Organization  TRUMP NATIONAL GOLF CLUB WASHINGTON DC MEMBER ...
# 3087  Organization                    TRUMP OCEAN MANAGING MEMBER LLC
# 3107  Organization                             TRUMP ORGANIZATION LLC
# 3111  Organization         TRUMP PANAMA HOTEL MANAGEMENT MEMBER CORP.
# 3114  Organization                         TRUMP PLAZA ASSOCIATES LLC
# 3124  Organization         TRUMP SALES & LEASING CHICAGO MEMBER CORP.
# 3126  Organization             TRUMP SCOTSBOROUGH SQUARE MEMBER CORP.
# 3127  Organization                         TRUMP TAJ MAHAL ASSOCIATES
# 3128  Organization                         TRUMP TORONTO MEMBER CORP.
# 3129  Organization                         TRUMP TORONTO MEMBER CORP.
# 3130  Organization                  TRUMP TOWER MANAGING MEMBER, INC.
# 3133  Organization                         TRUMP VINEYARD ESTATES LLC
# 3134  Organization             TRUMP VINEYARD ESTATES LOT 3 OWNER LLC
# 3138  Organization                 TRUMP VIRGINIA LOT 5 MANAGER CORP.
# 3141  Organization              TRUMP WORLD PRODUCTIONS MANAGER CORP.
# 3167  Organization                                               USAA
# 3178        Person                                   VIKTOR KHRAPUNOV
# 3179        Person                                   VLADIMIR POTANIN
#
#      Entity B Type                                           Entity B  \
# 5     Organization                           TRUMP CHICAGO RETAIL LLC
# 6     Organization                       TRUMP COMMERCIAL CHICAGO LLC
# 7     Organization                          TRUMP PAYROLL CHICAGO LLC
# 20    Organization                     TRUMP MARKS PUNTA DEL ESTE LLC
# 25    Organization                       THE TRUMP ORGANIZATION, INC.
# 49    Organization                     THE DONALD J. TRUMP FOUNDATION
# 50    Organization                THE DONALD J. TRUMP REVOCABLE TRUST
# 51    Organization                       THE TRUMP ORGANIZATION, INC.
# 53    Organization                   TRUMP INTERNATIONAL GOLF CLUB LC
# 54    Organization     TRUMP INTERNATIONAL GOLF CLUB SCOTLAND LIMITED
# 56    Organization                         TRUMP TOWER COMMERCIAL LLC
# 59    Organization            TRUMP NATIONAL GOLF CLUB COLTS NECK LLC
# 73    Organization                             TRUMP ORGANIZATION LLC
# 90    Organization                          THE ERIC TRUMP FOUNDATION
# 107   Organization                             TRUMP ORGANIZATION LLC
# 109   Organization                         TRUMP MODEL MANAGEMENT LLC
# 226   Organization                       THE TRUMP ORGANIZATION, INC.
# 231   Organization                          THE ERIC TRUMP FOUNDATION
# 238   Organization                          THE ERIC TRUMP FOUNDATION
# 280   Organization                       THE TRUMP ORGANIZATION, INC.
# 284   Organization         TRUMP NATIONAL GOLF CLUB WASHINGTON DC LLC
# 326   Organization                                    TRUMP KOREA LLC
# 327   Organization                                    TRUMP KOREA LLC
# 340   Organization                       THE TRUMP ORGANIZATION, INC.
# 417   Organization                               TRUMP NATIONAL DORAL
# 427   Organization  THE TRUMP ENTREPRENEUR INITIATIVE LLC (NY DOME...
# 438   Organization             TRUMP BRIARCLIFF MANOR DEVELOPMENT LLC
# 439   Organization                  TRUMP CHICAGO MANAGING MEMBER LLC
# 440   Organization                           TRUMP CHICAGO MEMBER LLC
# 441   Organization                TRUMP LAS VEGAS MANAGING MEMBER LLC
# ...            ...                                                ...
# 3070  Organization                               TRUMP MARKS SOHO LLC
# 3071  Organization                           TRUMP MARKS STAMFORD LLC
# 3072  Organization                      TRUMP MARKS SUNNY ISLES I LLC
# 3073  Organization                     TRUMP MARKS SUNNY ISLES II LLC
# 3075  Organization                            TRUMP MARKS TORONTO LLC
# 3077  Organization                            TRUMP MARKS WAIKIKI LLC
# 3078  Organization                        TRUMP MARKS WESTCHESTER LLC
# 3079  Organization                       TRUMP MARKS WHITE PLAINS LLC
# 3080  Organization                  TRUMP MIAMI RESORT MANAGEMENT LLC
# 3082  Organization              TRUMP NATIONAL GOLF CLUB - COLTS NECK
# 3083  Organization             TRUMP NATIONAL GOLF CLUB - WESTCHESTER
# 3084  Organization             TRUMP NATIONAL GOLF CLUB - WESTCHESTER
# 3085  Organization         TRUMP NATIONAL GOLF CLUB WASHINGTON DC LLC
# 3087  Organization                             TRUMP ON THE OCEAN LLC
# 3107  Organization                               TRUMP MARKS MMA, LLC
# 3111  Organization                  TRUMP PANAMA HOTEL MANAGEMENT LLC
# 3114  Organization                  TRUMP ENTERTAINMENT RESORTS, INC.
# 3124  Organization                  TRUMP SALES & LEASING CHICAGO LLC
# 3126  Organization                      TRUMP SCOTSBOROUGH SQUARE LLC
# 3127  Organization                TRUMP HOTELS & CASINO RESORTS, INC.
# 3128  Organization                             TRUMP MARKS TORONTO LP
# 3129  Organization              TRUMP TORONTO MANAGEMENT MEMBER CORP.
# 3130  Organization                         TRUMP TOWER COMMERCIAL LLC
# 3133  Organization             TRUMP VINEYARD ESTATES LOT 3 OWNER LLC
# 3134  Organization                       ERIC TRUMP LAND HOLDINGS LLC
# 3138  Organization                           TRUMP VIRGINIA LOT 5 LLC
# 3141  Organization                        TRUMP WORLD PRODUCTIONS LLC
# 3167  Organization                         TRUMP TOWER COMMERCIAL LLC
# 3178  Organization                              TRUMP SOHO MEMBER LLC
# 3179  Organization                             TRUMP ORGANIZATION LLC
#
#       Connection_Strength
# 5                0.852985
# 6                0.207837
# 7                0.910172
# 20               0.516288
# 25               0.569394
# 49               0.968860
# 50               0.528962
# 51               0.580072
# 53               0.267505
# 54               0.800504
# 56               0.785778
# 59               0.848742
# 73               0.955954
# 90               0.629689
# 107              0.741397
# 109              0.634903
# 226              0.833104
# 231              0.985400
# 238              0.724913
# 280              0.937458
# 284              0.925422
# 326              0.994785
# 327              0.618116
# 340              0.607196
# 417              0.922834
# 427              0.767323
# 438              0.961488
# 439              0.362045
# 440              0.907594
# 441              0.318025
# ...                   ...
# 3070             0.550959
# 3071             0.580284
# 3072             0.592550
# 3073             0.700992
# 3075             0.933211
# 3077             0.960088
# 3078             0.898137
# 3079             0.515148
# 3080             0.645157
# 3082             0.977906
# 3083             0.535413
# 3084             0.679488
# 3085             0.520484
# 3087             0.587488
# 3107             0.951712
# 3111             0.694004
# 3114             0.509241
# 3124             0.761927
# 3126             0.508324
# 3127             0.778367
# 3128             0.901042
# 3129             0.391436
# 3130             0.727837
# 3133             0.882507
# 3134             0.656043
# 3138             0.675189
# 3141             0.996642
# 3167             0.754582
# 3178             0.563763
# 3179             0.568327
#
# [194 rows x 5 columns]

# %%
# Test Cell: `Network_strong`
assert type(Network_strong)==pd.DataFrame, "Network_strong is not a panda dataframe"
assert list(Network_strong)==['Entity A Type','Entity A','Entity B Type','Entity B','Connection_Strength'], "Your Network_strong columns are not consistent with the master dataset"
assert len(Network_strong)==194, "The length of your Network_strong is not correct. Correct length should be 194."
test2 = Network_strong.sort_values(by='Connection_Strength')
test2.reset_index(drop=True, inplace=True)
assert math.isclose(test2.loc[0, 'Connection_Strength'], 0.039889119, rel_tol=1e-13)
assert math.isclose(test2.loc[100, 'Connection_Strength'], 0.744171895, rel_tol=1e-13)
assert math.isclose(test2.loc[193, 'Connection_Strength'], 0.996641965, rel_tol=1e-13)

print("\n(Passed.)")
# Out:
# (Passed.)

# %% [markdown]
# **Fin!** Remember to test your solutions by running them as the autograder will: restart the kernel and run all cells from "top-to-bottom." Also remember to submit to the autograder; otherwise, you will **not** get credit for your hard work!
